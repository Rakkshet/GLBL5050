# %% [markdown]
# All the President's Speeches
# 20 pts
#
# As we learned on Tuesday, word frequency distribution is an intuitive way of determining the major themes, topics, or even preoccupations of the speech giver. Pull texts from different US presidents and use FreqDist() to gain insights into the data. This is a fairly open assignment. The goal is to identify something interesting! Pull the text, tokenize, remove stopwords, and plot the frequency of the words. That's the technical part. But much of this assignment is your ability to use word frequency to gain insights comparatively, intra or inter presidents. Let the python notebook from our lecture be your guide! The more interesting and creative the analysis, the more points you will receive. We might pick one student's analysis to be displayed in lecture, and that person will receive bonus credit for the work.

# %%
import nltk
nltk.download()
from nltk import FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import inaugural
from nltk.corpus import stopwords
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (20,10))
cfd = nltk.ConditionalFreqDist((target, fileid[:4])
                               for fileid in inaugural.fileids()
                               for word in inaugural.words(fileid)
                               for target in ["war","peace"]
                               if word.lower().startswith(target))
                         
cfd.plot(title="References to War and Peace in Inaugural Address")
# Out:
# <Axes: title={'center': 'References to War and Peace in Inaugural Address'}, xlabel='Samples', ylabel='Counts'>

# %%
grant=inaugural.words("1873-Grant.txt")
carter=inaugural.words("1977-Carter.txt")
stopwords=nltk.corpus.stopwords.words("English")

new_stopwords=[';','In','I',',','.','--','-','We','And','us',':','one','"','much','know','another','?','that','like','That','The','This','It','But','but','i','¡¦','best','made','Our','My','upon','far','must','say','still','Let','cannot','Helen','SDGs','percent','need','also','would','many','turn','role','could','she','She','needed','comes','Again,','SDGs.']
stopwords.extend(new_stopwords)

new_stopwords2=["'","Helen's"]
stopwords.extend(new_stopwords2)

clean_grant=[]
for clean in grant:
    if not clean in stopwords:
        clean_grant.append(clean)

clean_carter=[]
for clean in carter:
    if not clean in stopwords:
        clean_carter.append(clean)

fdis_grant=FreqDist(clean_grant)

fdis_carter=FreqDist(clean_carter)

plt.figure(figsize=(8, 5))
fdis_grant.plot(20, title="Word Frequency Distributions for the Inaugural Addresses of President Grant")
plt.show()

plt.figure(figsize=(8, 5))
fdis_carter.plot(20, title="Word Frequency Distributions for the Inaugural Addresses of President Carter")
plt.show()

# %% [markdown]
# ## Intro to Scraping
#
# Text scraping, also known as web scraping or data scraping, refers to the process of automatically extracting text data from websites or other online sources.
#
# Below is some code for you to scrape a website. The package is called "Beautiful Soup" I have given you code below to use.
#
# I have given you TWO websites to scrape. PLEASE PICK ONE of TWO.
# Either:
#
# 1. A speech from Christine LaGrande on Sustainable Development Goals
# https://www.imf.org/en/News/Articles/2018/09/17/sp09172018-the-case-for-the-sustainable-development-goals'
# OR
# 2. "Joint Statement of the Russian Federation and the People’s Republic of China on the International Relations Entering a New Era and the Global Sustainable Development" Feb, 2022
# http://www.en.kremlin.ru/supplement/5770

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
 
base_url = "https://www.imf.org/en/News/Articles/2018/09/17/sp09172018-the-case-for-the-sustainable-development-goals"
r = requests.get(base_url)
soup = BeautifulSoup(r.text)
paragraphs = soup.find_all('p')

for p in paragraphs:
    print(p.get_text())
# Out:
# The IMF Press Center is a password-protected site for working journalists.
# Christine Lagarde
# The IMF Press Center is a password-protected site for working journalists.
# PRESS CENTER
#  Sign up to receive free e-mail notices when new series and/or country items are posted on the IMF website.
#  Modify your profile
# By Christine Lagarde,
# Managing Director, International Monetary Fund
# September 17, 2018
#
# Good evening.
#
#
# I am honored to join you tonight, for this inaugural lecture in memory of a
# remarkable woman—Dame Helen Alexander. I want to extend a special greeting
# to her husband Tim; her children Nina, Leo, and Gregory; and all of her
# family and friends gathered here this evening. Thank you Zanny for your
# kind invitation and thank you John for your gracious introduction. Let me
# also acknowledge Carolyn Fairbairn from the Confederation of British
# Industry, and all here from UBM and the University of Southampton.
#
#
# ...

# %% [markdown]
# 5 pts Modify the text above to write the text to a list called "document"

# %%
document = []
for p in paragraphs:
    document.append(p.get_text())
print(document)
# Out:
# ['The IMF Press Center is a password-protected site for working journalists.', 'Christine Lagarde', 'The IMF Press Center is a password-protected site for working journalists.', 'PRESS CENTER', ' Sign up to receive free e-mail notices when new series and/or country items are posted on the IMF website. ', ' Modify your profile', 'By Christine Lagarde,', 'Managing Director, International Monetary Fund', 'September 17, 2018', '\nGood evening.\n', '\nI am honored to join you tonight, for this inaugural lecture in memory of a\nremarkable woman—Dame Helen Alexander. I want to extend a special greeting\nto her husband Tim; her children Nina, Leo, and Gregory; and all of her\nfamily and friends gathered here this evening. Thank you Zanny for your\nkind invitation and thank you John for your gracious introduction. Let me\nalso acknowledge Carolyn Fairbairn from the Confederation of British\nIndustry, and all here from UBM and the University of Southampton.\n', '\nEach of us cherish our memori
# ...

# %% [markdown]
# 5 pts Write the code to a file called "document.txt"

# %%
with open("document.txt", "w", encoding="utf-8") as file:
    for text in document:
        file.write(text + "\n")

# %% [markdown]
# 20 pts Clean the document of any extraneous elements, remove stopwords and perform a word frequency distribution analysis on your document, showing and then plotting the top 20 words

# %%
document_words = []
for sentence in document:
    sentence_words = sentence.split()
    document_words.extend(sentence_words)

clean_document=[]
for clean in document_words:
    if not clean in stopwords:
        clean_document.append(clean)

fdis_document=FreqDist(clean_document)

plt.figure(figsize=(8, 5))
fdis_document.plot(20, title="Word Frequency Distributions for the Webpage")
plt.show()

# %% [markdown]
# 5 pts Please read the speech. What does the word frequency tell us, if anything, about the speech? Please answer in a short paragraph that tells me how the word frequency distribution is good at finding meaning, but also may miss the meaning that you gained from actually reading the article.

# %% [markdown]
# Your paragraph here: Going over the speech, it becomes evident that the frequency distribution offers insights into the main themes of the speech, such as economic growth, addressing social inequality, and the IMF's stance on these issues. However, it falls short in delivering the broader context in which these themes were discussed. It doesn't convey the speech's overarching objectives or what the audience can expect to derive from it.

# %% [markdown]
# ## Intro to Summarization
# Summarization has been a thorny problem for data scientists over the past decade. There have been many approaches, but most, until GPT have been unsatisfactory. There are two main types of summarization:
#
# 1. Extractive Summarization: Finding the most important sentences and rendering them verbatim.
#
# 2. Abstractive Summarization: Taking the most important ideas from a document and generating a summary based on them
#
#
# There have been many different algorithms that have attempted summarization. Let's learn about one of the most used and deploy it in python.

# %% [markdown]
# ### Luhns Heuristic Method
# This is one of the earliest approaches of text summarization. This is related to our manual interpretation of the importance of word frequency in a document.Basically, just as we did, Luhn recognized that word frequency and word significance is highly correlated, but only "important" words. The assumption that the most important sentences are those with the most significant words. Here is a nice short article that explains the algo in an accessible way: https://blog.fastforwardlabs.com/2016/03/25/h.p.-luhn-and-the-heuristic-value-of-simplicity.html

# %% [markdown]
# Sumy is a python package that has a lot of different commons summarization methods including LSA, LexRank and Luhn.

# %%
#install sumy package
# !pip install sumy

# %% [markdown]
# Run the following code. Pass the document you want to summarize as a variable in the document part of the statement below. Use the variable that you saved the document into if it's something different.
#
# PlaintextParser.from_string(document,Tokenizer("english"))

# %%
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer

parser = PlaintextParser.from_string(document,Tokenizer("english"))

summarizer_luhn = LuhnSummarizer()
summary_1 =summarizer_luhn(parser.document,2)
for sentence in summary_1:
    print(sentence)
# Out:
# This is partly\ndue to technology, partly due to global integration, and partly due to\npolicies that favor capital over labor.\n', '\nThe implications are alarming, especially among these advanced economies.\nIn these countries, rising inequality is contributing to the withering away\nof entire communities and ways of life; the unravelling of social cohesion\nand sense of a common destiny; and the growing tendency to replace\ndeliberation with demonization, partnership with parochialism.\n', '\nNaturally, this makes it much harder to reach agreement on the kinds of\npolicies and partnerships needed for the SDGs.\n', '\nIt is also not surprising that IMF research has found that reducing\ninequality is associated with stronger and more sustainable growth.\n', '\nA key issue here is that excessive inequality can undermine the idea of a\nmeritocratic society, as a small minority gain privileged access to the\nmany tangible and intangible benefits needed to get ahead—whether it is\neduca
# ...

# %% [markdown]
# 10 pts Evaluate the Luhn summarization below. How did it do?

# %% [markdown]
# Your evaluation here: While Luhn summarization performed better than basic frequency distribution in summarizing the speech, it still overlooks the essential structure of the speech. Throughout the address, a consistent structure was maintained, with each section addressing the problem, detailing prior efforts, and proposing future actions. Luhn summarization falls short in capturing this structure, as it only focuses on sentences with the highest word frequencies. It doesn't provide a clear picture.

# %% [markdown]
# 15 pts Now look at the documentation for Sumy and use the Lex Rank summarization algo.

# %%
from sumy.summarizers.lex_rank import LexRankSummarizer

parser = PlaintextParser.from_string(document, Tokenizer("english"))
summarizer_lex_rank = LexRankSummarizer()
summary = summarizer_lex_rank(parser.document, sentences_count=2)

for sentence in summary:
    print(sentence)
# Out:
# It is not only the right thing to do; it is the smart\nthing to do.
# This will not be easy, but I am convinced\nthat the world will be able to deploy its groundswell of global\nconsciousness to take the actions necessary to secure our collective\nfuture.\n', '\nWhat is the role of the IMF in this?

# %% [markdown]
# How does Lex Rank work? Explain it to me and evaluate the differences in the two algos.

# %% [markdown]
# 5 pts Your explanation and evaluation here:
# It seems that LexRank, an extractive text summarization algorithm, selects important sentences to create a summary by identifying which sentences encapsulate the most information in that particular set of documents based on their similarity to other sentences in the same document. Compared to Luhn summarization, it's shorter, which I presume is because it places weight on the sentences themselves rather than individual words. However, it appears to be a highly ineffective approach for summarizing a speech (at least the one that we read), as certain sentences are quite repetitive and do not add any substantial meaning to the speech.

# %% [markdown]
# ### Using ChatGPT for Summarization
# Now use Chatgpt to perform extractive and abstractive summarization on your document. Copy and paste into prompt. You will see that the document may be too long, so you will have to break the document into parts. Does where you break your document impact the summarization?

# %% [markdown]
# 5 pts Copy and paste the ChatGPT extractive summarization here:
#
# The speaker begins by honoring Dame Helen Alexander and highlighting her qualities as a remarkable woman. They focus on Helen's dedication, compassion, and commitment to human relationships.
#
# The speaker shifts the focus to the Sustainable Development Goals (SDGs), emphasizing the importance of practicality and decency in achieving these goals.
#
# The economic dimension is discussed, emphasizing the challenges faced by low-income countries in achieving the SDGs, including poverty, child mortality, and education gaps. The importance of human capital and partnership is highlighted.
#
# The social dimension is explored, addressing income inequality, gender equity, and the role of diversity in business leadership. The impact of gender inequality on economic growth and the need for inclusion are emphasized.
#
# The environmental dimension of the SDGs is discussed, highlighting the importance of addressing climate change and implementing carbon pricing. The role of the IMF in advising on energy transition and climate resilience is mentioned.
#
# The governance dimension is explored, emphasizing the significance of effective and accountable institutions. Corruption and tax avoidance are discussed as obstacles to achieving the SDGs. Transparency, accountability, and good governance are emphasized.
#
# The speech concludes by highlighting the importance of succeeding with the SDGs as a legacy for future generations, similar to the legacy left by Dame Helen Alexander.
#
# This summary provides an overview of the main points in the text.

# %% [markdown]
# 5 pts Copy and paste the ChatGPT abstractive summarization here:
#
# In this inaugural lecture delivered in memory of Dame Helen Alexander, the speaker reflects on the life and qualities of Dame Helen Alexander. He describes her as fiercely intelligent, tenacious, compassionate, and someone who always prioritized human relationships. He acknowledges the presence of Helen's family and friends in the audience.
#
# The central focus of the lecture is on the Sustainable Development Goals (SDGs), a global policy roadmap established in 2015 to address various global challenges by 2030. The speaker identifies the SDGs as a response to the challenges of the 21st century and emphasizes their importance in addressing issues of global trust and cooperation.
#
# The lecture delves into four dimensions related to the SDGs:
#
# 1. **Economic Dimension:** Discussing the challenges of low-income countries in achieving the SDGs, including issues of poverty, healthcare, education, and access to resources. The speaker underscores the importance of strong partnerships to meet the additional spending needs of low-income countries and the role of the international community.
#
# 2. **Social Dimension:** Emphasizing the need to address income inequality and gender equity. The lecture highlights the impact of income inequality on social cohesion and the importance of gender equity in labor force participation.
#
# 3. **Environmental Dimension:** Discussing the imperative of respecting the planet's natural limits in economic progress, particularly in the context of climate change. The speaker advocates for carbon pricing and emphasizes the role of the IMF in nudging the global transition towards a zero-carbon economy.
#
# 4. **Governance Dimension:** Stressing the significance of good governance and institutions in achieving the SDGs. The lecture addresses issues of corruption, tax avoidance, and the role of transparency and accountability in strong economic institutions.
#
# The speaker references Helen Alexander's values of honesty, impartiality, and integrity and how these values are crucial in addressing governance and corruption issues. The lecture concludes by emphasizing the legacy that will be left for future generations in the pursuit of the SDGs.
#
# Overall, the lecture pays tribute to Dame Helen Alexander's legacy and connects her values to the global efforts to achieve sustainable development through the SDGs.

# %% [markdown]
# 5 pts Does breaking the document in different places impact the summarization?
# Answer here: While I was able to summarize the speech without breaking its flow, I believe it's important to highlight that the placement of breaks within the speech could influence the interpretation of certain ideas, potentially changing the overall summary.

# %% [markdown]
# ## Pizza Problem
#
# Elm City Pizza, a local Pizza company, is very short on staff and has hired you to write a script to take online pizza orders. The Pizza restaurant is a Vegan establishment and will not serve people who are not Vegan.
#
# Write a script that when a user enters the correct phone number (203-555-5555), prints "Elm City Pizza, a vegan restaurant for vegans only. My name is Moonchild, what's your name?"
# The user then enters their name.
# The response should print "Wow (users name) what an awesome name. What would you like to order?" and then offers an input statement.
#
# The menu is limited. There is pizza and there are salads. If the user asks for anything else print "Sorry,(users name) we don't have that." And then prompts them again with a different input statement, "How about a super awesome pizza? Take a look at our menu, you'll find its delicious."
#
# Here is the Menu.
#
# MENU:
# Pizza: The Basic: Tomato and Cashew Cream Cheese
# Small: 6.95
# Medium: 8.95
# Large 10.90
#
# Pizza Toppings (each additional topping, .50): Shitake, Jackfruit, Sweet Potato, Hummus, Chickpeas, Lentils, Tofu,  Edamame, Black Bean, Red Cabbage, Cucumber, Tomato, Jicama, Fried Green Tomatoes, Sun Dried Tomatoes,
#
# Salads: Vegan Caesar, Vegan Greek, Cucumber_Tumeric_Tomato
# Small: 4.95
# Large: 6.95
#
#
# If the user asks for any meat or if they ask for "normal" cheeses (mozerella, parmesian) on their pizza, the response should be "Sorry, (user name) but you are not vegan." and severs the contact (breaks the loop), forcing them to "call back" (enter the number again). But if they use the same name when they call back, the output should read "Sorry (user name) but I told you this is for vegans only. Call us back when you are vegan." If the user calls back with a different name. Take their order.
#
# For the user that does not make those mistakes (above), take their order. Prompt the user with "Anything else?" at each point in their order. They can add what they want until they input, "No that's it." At that point summarize their order, and tell them how much it will cost.
#
# Test your code with different conditions. Make sure it cannot be broken by flawed or deliberately malicious user inputs. You may use functions for modularity and to organize your code, but you don't have to. As long as it works!

# %%
import sys

salad_types = ["Vegan Caesar", "Vegan Greek", "Cucumber Turmeric Tomato"]
small_salad = "Small"
large_salad = "Large"
small_salad_price = 4.95
large_salad_price = 6.95

pizza_types = "The Basic: Tomato and Cashew Cream Cheese"
pizza_toppings = ["Shiitake", "Jackfruit", "Sweet Potato", "Hummus", "Chickpeas", "Lentils", "Tofu", "Edamame", "Black Bean", "Red Cabbage", "Cucumber", "Tomato", "Jicama", "Fried Green Tomato", "Sun-Dried Tomatoes"]
pizza_toppings_price = 0.50
small_pizza = "Small"
medium_pizza = "Medium"
large_pizza = "Large"
small_pizza_price = 6.95
medium_pizza_price = 8.95
large_pizza_price = 10.90

def pizza_menu():
    pizza_sizes_prices = {
        small_pizza: small_pizza_price,
        medium_pizza: medium_pizza_price,
        large_pizza: large_pizza_price
    }

    print(f"\033[1mPizza Type:\033[0m {pizza_types}")
    print("\033[1mPizza Sizes:\033[0m")
    for size, price in pizza_sizes_prices.items():
        print(f"{size}: ${price:.2f}")
    
def salad_menu():
    salad_sizes_prices = {
        small_salad: small_salad_price,
        large_salad: large_salad_price
    }

    print(f"\033[1mSalad Types:\033[0m {', '.join(salad_types)}")
    print("\033[1mSalad Sizes:\033[0m")
    for size, price in salad_sizes_prices.items():
        print(f"{size}: ${price:.2f}")

def add_to_order(order_total):
    while True:
        add_more = input("Do you want to add more items to your order (Yes/No)? ")
        if add_more == "No":
            return order_total
        elif add_more == "Yes":
            choice = input("Great! Would you like a Pizza or Salad?")
            if choice == "Pizza":
                print("Perfect! We have the following options")
                print()
                pizza_menu()
                print()
                while True:
                    pizza_option = input("What kind of Pizza would you like?")
                    if pizza_option == pizza_types:
                        print()
                        while True:
                            pizza_size = input(f"What size of {pizza_option} pizza would you like?")
                            if pizza_size == small_pizza:
                                print()
                                pizza_toppings_list_small = []
                                while True:
                                    pizza_toppings_option = input("Would you like a pizza topping (Yes/No)? Each pizza topping would cost an additional $0.5.")
                                    if pizza_toppings_option == "Yes":
                                        while True:
                                            pizza_toppings_kind = input(f"What pizza topping would you like? We have {', '.join(pizza_toppings)}.")
                                            if pizza_toppings_kind in pizza_toppings:
                                                pizza_toppings_list_small.append(pizza_toppings_kind)
                                                pizza_toppings_option2 = input("Would you like another topping (Yes/No)?")
                                                if pizza_toppings_option2 == "Yes":
                                                    continue
                                                else:
                                                    toppings_text = ", ".join(pizza_toppings_list_small)
                                                    pizza_price = small_pizza_price + len(pizza_toppings_list_small) * pizza_toppings_price
                                                    order_total += pizza_price
                                                    print()
                                                    print(f"A {pizza_size} {pizza_option} with {toppings_text} has been added to the cart.")
                                                    break
                                            elif pizza_toppings_kind == "Mozerella":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            elif pizza_toppings_kind == "Parmesian":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            else:
                                                print()
                                                print("Please pick a pizza topping from the menu.")
                                        break
                                    else:
                                        pizza_price = small_pizza_price
                                        order_total += pizza_price
                                        print()
                                        print(f"A {pizza_size} {pizza_option} has been added to the cart.")
                                        break
                                break
                            elif pizza_size == medium_pizza:
                                print()
                                pizza_toppings_list_medium = []
                                while True:
                                    pizza_toppings_option = input("Would you like a pizza topping (Yes/No)? Each pizza topping would cost an additional $0.5.")
                                    if pizza_toppings_option == "Yes":
                                        while True:
                                            pizza_toppings_kind = input(f"What pizza topping would you like? We have {', '.join(pizza_toppings)}.")
                                            if pizza_toppings_kind in pizza_toppings:
                                                pizza_toppings_list_medium.append(pizza_toppings_kind)
                                                pizza_toppings_option2 = input("Would you like another topping (Yes/No)?")
                                                if pizza_toppings_option2 == "Yes":
                                                    continue
                                                else:
                                                    toppings_text = ", ".join(pizza_toppings_list_medium)
                                                    pizza_price = medium_pizza_price + len(pizza_toppings_list_medium) * pizza_toppings_price
                                                    order_total += pizza_price
                                                    print()
                                                    print(f"A {pizza_size} {pizza_option} with {toppings_text} has been added to the cart.")
                                                    break
                                            elif pizza_toppings_kind == "Mozerella":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            elif pizza_toppings_kind == "Parmesian":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            else:
                                                print()
                                                print("Please pick a pizza topping from the menu.")
                                        break
                                    else:
                                        pizza_price = medium_pizza_price
                                        order_total += pizza_price
                                        print()
                                        print(f"A {pizza_size} {pizza_option} has been added to the cart.")
                                        break
                                break
                            elif pizza_size == large_pizza:
                                print()
                                pizza_toppings_list_large = []
                                while True:
                                    pizza_toppings_option = input("Would you like a pizza topping (Yes/No)? Each pizza topping would cost an additional $0.5.")
                                    if pizza_toppings_option == "Yes":
                                        while True:
                                            pizza_toppings_kind = input(f"What pizza topping would you like? We have {', '.join(pizza_toppings)}.")
                                            if pizza_toppings_kind in pizza_toppings:
                                                pizza_toppings_list_large.append(pizza_toppings_kind)
                                                pizza_toppings_option2 = input("Would you like another topping (Yes/No)?")
                                                if pizza_toppings_option2 == "Yes":
                                                    continue
                                                else:
                                                    toppings_text = ", ".join(pizza_toppings_list_large)
                                                    pizza_price = large_pizza_price + len(pizza_toppings_list_large) * pizza_toppings_price
                                                    order_total += pizza_price
                                                    print()
                                                    print(f"A {pizza_size} {pizza_option} with {toppings_text} has been added to the cart.")
                                                    break
                                            elif pizza_toppings_kind == "Mozerella":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            elif pizza_toppings_kind == "Parmesian":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            else:
                                                print()
                                                print("Please pick a pizza topping from the menu.")
                                        break
                                    else:
                                        pizza_price = large_pizza_price
                                        order_total += pizza_price
                                        print()
                                        print(f"A {pizza_size} {pizza_option} has been added to the cart.")
                                        break
                                break
                            else:
                                print()
                                print(f"We don't have {pizza_size} {pizza_option} pizza. Please pick from the menu.")
                        break
                    else:
                        print()
                        print(f"We don't have {pizza_option} pizza. Please pick from the menu.")
                break
            elif choice == "Salad":
                print("Perfect! We have the following options")
                print()
                salad_menu()
                print()
                while True:
                    salad_option = input("What kind of Salad would you like?")
                    if salad_option in salad_types:
                        print()
                        while True:
                            salad_size = input(f"What size of {salad_option} salad would you like?")
                            if salad_size == small_salad:
                                print()
                                print(f"A {salad_size} {salad_option} has been added to the cart.")
                                order_total += small_salad_price
                                break
                            elif salad_size == large_salad:
                                print()
                                print(f"A {salad_size} {salad_option} has been added to the cart.")
                                order_total += large_salad_price
                                break
                            else:
                                print()
                                print(f"We don't have {salad_size} {salad_option} salad. Please pick from the menu.")
                        break
                    else:
                        print()
                        print(f"We don't have {salad_option} salad. Please pick from the menu.")
                break
            else:
                print()
                print(f"Sorry {name}, we don't have that.")
                print()
                print("How about a super awesome pizza? Take a look at our menu; you'll find it delicious")
                print()
                pizza_menu()
                print()
                salad_menu()
        break
    return order_total

elm_city_pizza_number = "203-555-5555"

while True:
    phone_number = input("Please enter the phone number in the format: XXX-XXX-XXXX: ")

    if phone_number == elm_city_pizza_number:
        print()
        name = input("Elm City Pizza, a vegan restaurant for vegans only. My name is Moonchild, what's your name? ")
        print()
        print(f"Wow, {name}, what an awesome name!")

        order_total_first = 0

        while True:
            order = input("What would you like to order, a Pizza or Salad? ")
            if order == "Pizza":
                print("Perfect! We have the following options")
                print()
                pizza_menu()
                print()
                while True:
                    pizza_option = input("What kind of Pizza would you like?")
                    if pizza_option == pizza_types:
                        print()
                        while True:
                            pizza_size = input(f"What size of {pizza_option} pizza would you like?")
                            if pizza_size == small_pizza:
                                print()
                                pizza_toppings_list_small = []
                                while True:
                                    pizza_toppings_option = input("Would you like a pizza topping (Yes/No)? Each pizza topping would cost an additional $0.5.")
                                    if pizza_toppings_option == "Yes":
                                        while True:
                                            pizza_toppings_kind = input(f"What pizza topping would you like? We have {', '.join(pizza_toppings)}.")
                                            if pizza_toppings_kind in pizza_toppings:
                                                pizza_toppings_list_small.append(pizza_toppings_kind)
                                                pizza_toppings_option2 = input("Would you like another topping (Yes/No)?")
                                                if pizza_toppings_option2 == "Yes":
                                                    continue
                                                else:
                                                    toppings_text = ", ".join(pizza_toppings_list_small)
                                                    pizza_price = small_pizza_price + len(pizza_toppings_list_small) * pizza_toppings_price
                                                    order_total_first += pizza_price
                                                    print()
                                                    print(f"A {pizza_size} {pizza_option} with {toppings_text} has been added to the cart.")
                                                    break
                                            elif pizza_toppings_kind == "Mozerella":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            elif pizza_toppings_kind == "Parmesian":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            else:
                                                print()
                                                print("Please pick a pizza topping from the menu.")
                                        break
                                    else:
                                        pizza_price = small_pizza_price
                                        order_total_first += pizza_price
                                        print()
                                        print(f"A {pizza_size} {pizza_option} has been added to the cart.")
                                        break
                                break
                            elif pizza_size == medium_pizza:
                                print()
                                pizza_toppings_list_medium = []
                                while True:
                                    pizza_toppings_option = input("Would you like a pizza topping (Yes/No)? Each pizza topping would cost an additional $0.5.")
                                    if pizza_toppings_option == "Yes":
                                        while True:
                                            pizza_toppings_kind = input(f"What pizza topping would you like? We have {', '.join(pizza_toppings)}.")
                                            if pizza_toppings_kind in pizza_toppings:
                                                pizza_toppings_list_medium.append(pizza_toppings_kind)
                                                pizza_toppings_option2 = input("Would you like another topping (Yes/No)?")
                                                if pizza_toppings_option2 == "Yes":
                                                    continue
                                                else:
                                                    toppings_text = ", ".join(pizza_toppings_list_medium)
                                                    pizza_price = medium_pizza_price + len(pizza_toppings_list_medium) * pizza_toppings_price
                                                    order_total_first += pizza_price
                                                    print(f"A {pizza_size} {pizza_option} with {toppings_text} has been added to the cart.")
                                                    break
                                            elif pizza_toppings_kind == "Mozerella":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            elif pizza_toppings_kind == "Parmesian":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            else:
                                                print()
                                                print("Please pick a pizza topping from the menu.")
                                        break
                                    else:
                                        pizza_price = medium_pizza_price
                                        order_total_first += pizza_price
                                        print()
                                        print(f"A {pizza_size} {pizza_option} has been added to the cart.")
                                        break
                                break
                            elif pizza_size == large_pizza:
                                print()
                                pizza_toppings_list_large = []
                                while True:
                                    pizza_toppings_option = input("Would you like a pizza topping (Yes/No)? Each pizza topping would cost an additional $0.5.")
                                    if pizza_toppings_option == "Yes":
                                        while True:
                                            pizza_toppings_kind = input(f"What pizza topping would you like? We have {', '.join(pizza_toppings)}.")
                                            if pizza_toppings_kind in pizza_toppings:
                                                pizza_toppings_list_large.append(pizza_toppings_kind)
                                                pizza_toppings_option2 = input("Would you like another topping (Yes/No)?")
                                                if pizza_toppings_option2 == "Yes":
                                                    continue
                                                else:
                                                    toppings_text = ", ".join(pizza_toppings_list_large)
                                                    pizza_price = large_pizza_price + len(pizza_toppings_list_large) * pizza_toppings_price
                                                    order_total_first += pizza_price
                                                    print()
                                                    print(f"A {pizza_size} {pizza_option} with {toppings_text} has been added to the cart.")
                                                    break
                                            elif pizza_toppings_kind == "Mozerella":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            elif pizza_toppings_kind == "Parmesian":
                                                print()
                                                print(f"Sorry {name}, you are not a Vegan")
                                                raise SystemExit
                                            else:
                                                print()
                                                print("Please pick a pizza topping from the menu.")
                                        break
                                    else:
                                        pizza_price = large_pizza_price
                                        order_total_first += pizza_price
                                        print()
                                        print(f"A {pizza_size} {pizza_option} has been added to the cart.")
                                        break
                                break
                            else:
                                print()
                                print(f"We don't have {pizza_size} {pizza_option} pizza. Please pick from the menu.")
                        break
                    else:
                        print()
                        print(f"We don't have {pizza_option} pizza. Please pick from the menu.")
                add_to_order(order_total_first)  # Add more items to the order
                break
            elif order == "Salad":
                print("Perfect! We have the following options")
                print()
                salad_menu()
                print()
                while True:
                    salad_option = input("What kind of Salad would you like?")
                    if salad_option in salad_types:
                        print()
                        while True:
                            salad_size = input(f"What size of {salad_option} salad would you like?")
                            if salad_size == small_salad:
                                print()
                                print(f"A {salad_size} {salad_option} has been added to the cart.")
                                order_total_first += small_salad_price
                                break
                            elif salad_size == large_salad:
                                print()
                                print(f"A {salad_size} {salad_option} has been added to the cart.")
                                order_total_first += large_salad_price
                                break
                            else:
                                print()
                                print(f"We don't have {salad_size} {salad_option} salad. Please pick from the menu.")
                        break
                    else:
                        print()
                        print(f"We don't have {salad_option} salad. Please pick from the menu.")
                order_total_first = add_to_order(order_total_first)
                break
            else:
                print()
                print(f"Sorry {name}, we don't have that.")
                print()
                print("How about a super awesome pizza? Take a look at our menu; you'll find it delicious")
                print()
                pizza_menu()
                print()
                salad_menu()
        break
    else:
        print()
        print("Wrong number! Please try again.")

order_total_final = add_to_order(order_total_first)

print()
print("Thank you for your order!")
print()
print(f"Your total order amount is ${order_total_final:.2f}")
# Out:
# Please enter the phone number in the format: XXX-XXX-XXXX: 203-555-5555
#
# Elm City Pizza, a vegan restaurant for vegans only. My name is Moonchild, what's your name? Rakkshet
#
# Wow, Rakkshet, what an awesome name!
# What would you like to order, a Pizza or Salad? Salad
# Perfect! We have the following options
#
# Salad Types: Vegan Caesar, Vegan Greek, Cucumber Turmeric Tomato
# Salad Sizes:
# Small: $4.95
# Large: $6.95
#
# What kind of Salad would you like?Vegan Greek
#
# What size of Vegan Greek salad would you like?Small
#
# A Small Vegan Greek has been added to the cart.
# Do you want to add more items to your order (Yes/No)? Yes
# Great! Would you like a Pizza or Salad?Pizza
# Perfect! We have the following options
#
# Pizza Type: The Basic: Tomato and Cashew Cream Cheese
# Pizza Sizes:
# Small: $6.95
# Medium: $8.95
# Large: $10.90
#
# What kind of Pizza would you like?The Basic: Tomato and Cashew Cream Cheese
#
# ...
